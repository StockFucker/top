# %%
import pandas as pd
from utils import *

# %%
len(data_df)
# Out:
# 29238

# %%
valid_df = data_df[data_df["volume1"] / data_df["volume0"] > 1]
# valid_df = data_df[data_df["volume1"] / data_df["volume0"] < 1.2]
valid_df = valid_df[data_df["minute_volume"] / data_df["volume1"] < 0.6]
valid_df = valid_df[data_df["low2"] / data_df["close1"] > 0.98]
# valid_df = valid_df[data_df["minute"] > "10:30:00"]
valid_df = valid_df[((data_df["recent"] > 1) | (data_df["wave"] > 1))]
# valid_df = valid_df[data_df["open2"] > data_df["close1"] * 1.06]
# valid_df = valid_df[data_df["open2"] < data_df["close1"] * 1.06]
# valid_df = valid_df[data_df["open2"]/data_df["low2"] > 1.0]
# valid_df = valid_df[data_df["minute"] <= "09:32:00"]
# valid_df = valid_df[valid_df["high_limit2"]/valid_df["open2"] < 1.03]

valid_df = valid_df[data_df["recent_high"]/data_df["high_limit2"] < 0.9]
# valid_df = valid_df[data_df["recent_high"]/data_df["high_limit2"] < 1.0]
# valid_df = valid_df[~((data_df["volume_high"] < data_df["volume1"]) | (data_df["nearby"] >= 3))]
# valid_df = valid_df[data_df["isnew"] == True]
valid_df = valid_df[data_df["volume_mean"]/data_df["volume1"] < 0.2]
# valid_df = valid_df[data_df["volume_mean"] / data_df["volume1"] < 0.2]
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
valid_df = valid_df.sort_values("minute")
valid_df = valid_df.groupby("date").first()
result(valid_df)
# Out:
#             mean  count
# recent
# 1.0     1.018068     10
# 2.0     1.028108    131
# 3.0     1.014474     94
# 4.0     1.028963     37
# 5.0     1.074482      9
# 6.0     1.038267      3
# 7.0     1.012217      7
# 0.637583892617 298 1.02434454582

# %%
def get_date(name):
    se = valid_df.ix[name]
    return se["change"],se["volume1"]/se["volume0"],se["minute_volume"]/se["volume1"],se["low2"]/se["close1"],\
    se["open2"]/se["low2"],se["recent"],se["minute"],se.nearby,se.wave,se.recent_high/se.high_limit2,se.top_count,se["volume_high"]/se["volume1"],se["volume_mean"]/se["volume1"],se["open2"]/se["close1"]

# %%
indexs = ["601116.XSHG_2016-12-07","601116.XSHG_2016-12-14","601116.XSHG_2016-12-01"]
indexs = indexs + ["000912.XSHE_2016-09-29","600069.XSHG_2016-12-13","002302.XSHE_2017-03-24","600242.XSHG_2017-03-22"]
# indexs = ["000035.XSHE_2016-09-08","000035.XSHE_2016-10-18",""]
output_df = pd.DataFrame(columns = ["change","volume1/0","volume2/1","lo2/close1","open2/low2","recent","minute","nearby","wave","recent_high/high2","top_count","recent_volume/volume1","volume_Mean/volume1","open2/close1"])
for index in indexs:
    output = get_date(index)
    output_df.ix[index] = output
output_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-1c261654a0f7> in <module>()
#       4 output_df = pd.DataFrame(columns = ["change","volume1/0","volume2/1","lo2/close1","open2/low2","recent","minute","nearby","wave","recent_high/high2","top_count","recent_volume/volume1","volume_Mean/volume1","open2/close1"])
#       5 for index in indexs:
# ----> 6     output = get_date(index)
#       7     output_df.ix[index] = output
#       8 output_df
#
# <ipython-input-37-91a03824c32a> in get_date(name)
#       1 def get_date(name):
# ----> 2     se = valid_df.ix[name]
#       3     return se["change"],se["volume1"]/se["volume0"],se["minute_volume"]/se["volume1"],se["low2"]/se["close1"],    se["open2"]/se["low2"],se["recent"],se["minute"],se.nearby,se.wave,se.recent_high/se.high_limit2,se.top_count,se["volume_high"]/se["volume1"],se["volume_mean"]/se["volume1"],se["open2"]/se["close1"]
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      85         else:
#      86             key = com._apply_if_callable(key, self.obj)
# ---> 87             return self._getitem_axis(key, axis=0)
#      88
#      89     def _get_label(self, label, axis=0):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1030                     return self._get_loc(key, axis=axis)
#    1031
# -> 1032             return self._get_label(key, axis=axis)
#    1033
#    1034     def _getitem_iterable(self, key, axis=0):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_label(self, label, axis)
#     100             raise IndexingError('no slices here, handle elsewhere')
#     101
# --> 102         return self.obj._xs(label, axis=axis)
#     103
#     104     def _get_loc(self, key, axis=0):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, drop_level)
#    1777                                                       drop_level=drop_level)
#    1778         else:
# -> 1779             loc = self.index.get_loc(key)
#    1780
#    1781             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: '601116.XSHG_2016-12-01'

# %%
valid_df["change0"] = valid_df["volume1"] / valid_df["volume0"]

# %%
valid_df
# Out:
#                        change             last_day        stock  close0  \
# date
# 2007-02-06 00:00:00  1.065217  2007-02-05 00:00:00  600842.XSHG    4.84
# 2007-02-12 00:00:00  1.004093  2007-02-09 00:00:00  600842.XSHG    6.68
# 2009-02-18 00:00:00  1.008969  2009-02-17 00:00:00  600667.XSHG    2.16
# 2009-04-09 00:00:00  1.040602  2009-04-08 00:00:00  600756.XSHG    5.87
# 2009-07-20 00:00:00  1.004324  2009-07-17 00:00:00  000809.XSHE    8.85
# 2009-11-23 00:00:00  1.100683  2009-11-20 00:00:00  600186.XSHG    5.31
# 2010-11-11 00:00:00  1.017241  2010-11-10 00:00:00  600986.XSHG   10.35
# 2010-11-29 00:00:00  1.022099  2010-11-26 00:00:00  600851.XSHG    6.68
# 2011-02-28 00:00:00  0.994975  2011-02-25 00:00:00  600736.XSHG    5.43
# 2011-06-14 00:00:00  1.003827  2011-06-13 00:00:00  000534.XSHE    7.00
# 2012-04-18 00:00:00  0.984508  2012-04-17 00:00:00  600198.XSHG   11.24
# 2012-10-22 00:00:00  1.060453  2012-10-19 00:00:00  600609.XSHG    3.59
# 2013-01-07 00:00:00  1.059364  2013-01-04 00:00:00  002151.XSHE   12.54
# 2013-01-10 00:00:00  1.048611  2013-01-09 00:00:00  002151.XSHE   15.56
# 2013-01-16 00:00:00  1.035714  2013-01-15 00:00:00  300325.XSHE    1.95
# 2013-01-21 00:00:00  1.000000  2013-01-18 00:00:00  600683.XSHG    5.32
# 2013-02-28 00:00:00  0.908960  2013-02-27 00:00:00  600732.XSHG    5.89
# 2013-03-20 00:00:00  1.059974  2013-03-19 00:00:00  000797.XSHE    6.43
