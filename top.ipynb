# %%
import pandas as pd

# %%
df = pd.read_csv("output2.csv",index_col=0)

# %%
df = df.sort("mean")
df.tail(50)
# Out:
# /Users/sgcy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                               win_ratio      mean  count
# opentop0-speedup2-minute                       0.846154  1.044382     13
# opentop0-jump1-speedup2                        0.625000  1.044474     32
# opentop0-jump2-speedup1-speedup2-volume        0.950000  1.044760     20
# opentop0-foot2-speedup2                        0.733333  1.044763     15
# notyz1-yz0-jump2-foot2-minute                  0.736842  1.044900     19
# opentop0-jump1-speedup2-minute                 0.612903  1.044920     31
# opentop0-opentop2-notyz1-jump1                 0.612903  1.045054     31
# opentop0-notyz1-jump1-jump2-volume             0.733333  1.045154     15
# opentop0-foot1-speedup2-minute                 0.857143  1.045253     14
# ...

# %%
# Out:
#                                                     win_ratio      mean  count
# opentop0-yz0-top0-top1-jump1-foot0-speedup2-volume   0.714286  1.024042     21
# opentop1-top0-top1-jump1-jump2-speedup2-minute       0.718750  1.025735     32
# opentop0-notyz1-yz0-top0-top1-jump1-foot0-volume     0.720000  1.030831     25
# opentop0-opentop1-notyz1-top1-jump1-jump2            0.720930  1.021247     43
# notyz1-top0-jump1-jump2-foot0-minute-volume          0.722222  1.028497     18
# opentop1-notyz0-notyz1-speedup2-minute               0.724138  1.028898     29
# opentop1-notyz1-jump1-speedup2-minute-volume         0.727273  1.027211     33
# opentop1-speedup2-minute                             0.729730  1.025609     37
# opentop0-top0-top1-foot0-speedup2-minute-volume      0.733333  1.024512     30
# opentop1-notyz0-notyz1-top0-nottop1-speedup2-mi...   0.734694  1.022698     49
# notyz0-notyz1-top0-top1-jump2-foot2-volume           0.736842  1.026949     19
# ...

# %%
sub_df = df[df["count"] > 50]
sub_df.tail(100)
# Out:
#                                            win_ratio      mean  count
# opentop0-opentop1-notyz1-top1-jump1         0.614458  1.023622     83
# opentop0-opentop1-notyz1                    0.615385  1.020668    104
# opentop0-notyz1-jump2                       0.625000  1.026576     72
# opentop0-notyz0-notyz1-top0-minute-volume   0.626866  1.024013     67
# opentop0-opentop1-notyz1-top1               0.627451  1.021488    102
# opentop0-notyz0-notyz1-top0-minute          0.627907  1.022555     86
# opentop0-notyz1-foot0-minute                0.629630  1.020292    135
# opentop0-notyz1-jump1-foot0-minute          0.629921  1.021139    127
# opentop0-notyz1-jump2-minute                0.630769  1.029690     65
# opentop0-notyz1-jump2-foot0-minute          0.631579  1.023402     57
# opentop0-notyz0-notyz1-minute               0.632184  1.022810     87
# opentop0-notyz0-notyz1-minute-volume        0.632353  1.024318     68
# ...

# %%
df = df[~df["mean"].duplicated()]
